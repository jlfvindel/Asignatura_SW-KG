# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jlfvindel/SW-KG/blob/main/RDFlib/SPARQLWrapper-Colab.ipynb)

# %% [markdown]
# ## Consultas con SPARQLWrapper

# %% [markdown]
# ### Resumen de este cuaderno
# + Se instancian clientes [SPARQLWrapper](https://sparqlwrapper.readthedocs.io/en/latest/main.html) para consultas a datastores externos
# + Las [consultas SPARQL](https://www.w3.org/TR/2013/REC-sparql11-query-20130321/) ejecutadas son todas de tipo SELECT
# + Se solicita el retorno de datos en el formato [JSON estándar para respuestas](https://www.w3.org/TR/sparql11-results-json/) a consultas SPARQL SELECT
# + Los datos recibidos se reorganizan como un dataframe para su presentación tabular

# %% [markdown]
# ### Cuatro tipos de consultas
# En la [panorámica sobre SPARQL](https://www.w3.org/TR/sparql11-overview/) se describe que consta de un protocolo de acceso a datastores y que es tanto un lenguaje de administración como de consulta. Como lenguaje de consulta facilta 4 tipos de consultas:
# + Las consultas de tipo CONSTRUCT o DESCRIBE devuelven un grafo
# + Las consulta de tipo ASK devuelven un valor booleano
# + Y las consultas de tipo SELECT devuelven un conjunto de resultados: n-tuplas intuitivamente percibidas como filas de una tabla con n columnas etiquetadas.

# %% [markdown]
# ### Formatos de retorno
# + Las consultas SELECT o ASK devuelven conjuntos de resultados independientes, que se pueden recibir en formato  [JSON](http://www.w3.org/TR/sparql11-results-json/), [XML](http://www.w3.org/TR/rdf-sparql-XMLres/) o [CSV/TSV](http://www.w3.org/TR/sparql11-results-csv-tsv/)
# + Las consultas CONSTRUCT o DESCRIBE devuelven grafos, que se pueden secuenciar en cualquiera de los [formatos para grafos RDF](https://www.w3.org/TR/rdf11-primer/#section-graph-syntax): N3, Turtle, RDF/XML, JSON-LD

# %% [markdown]
# ### Dos opciones de SPARQLWrapper
# Del paquete SPARQLWrapper se utiliza el módulo Wrapper y su clase [SPARQLWrapper]((https://sparqlwrapper.readthedocs.io/en/latest/SPARQLWrapper.Wrapper.html#SPARQLWrapper.Wrapper.SPARQLWrapper)) para configurar todo tipo de conexión y de consulta SPARQL, con todo tipo de formato de retorno.
#
# El paquete SPARQLWrapper contiene también el módulo SmartWrapper, que contiene la clase [SPARQLWrapper2]((https://sparqlwrapper.readthedocs.io/en/latest/SPARQLWrapper.SmartWrapper.html#SPARQLWrapper.SmartWrapper.SPARQLWrapper2)), una versión con sintaxis simplificada porque asume que las consultas son de tipo SELECT y el formato de retorno es JSON.

# %% [markdown]
# ## Ejecución de la consulta

# %% [markdown]
# ### Instanciación del cliente de consulta
# Se supone que [el paquete SPARQLWrapper](https://sparqlwrapper.readthedocs.io/en/latest/main.html) está instalado. El siguiente código instancia un cliente de consulta SPARQLWrapper dirigido a Wikidata

# %%
# Comente o descomente conforme esté o no instalado
# !pip install SPARQLWrapper

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

servidor = "https://query.wikidata.org/sparql" 
cliente = SPARQLWrapper(servidor)

print(f'Se ha creado un cliente de consulta a {cliente.endpoint}\n \
      que asume por defecto respuesta en formato {cliente.returnFormat}')
# Out:
# Se ha creado un cliente de consulta a https://query.wikidata.org/sparql
#        que asume por defecto respuesta en formato xml

# %% [markdown]
# Se cambia el formato de respuesta solicitado a JSON.

# %%
cliente.setReturnFormat(JSON)
print(f'Formato de retorno fijado a {cliente.returnFormat}.\n \
     ¿Confirma el servidor que lo acepta? : \
     {cliente.supportsReturnFormat(cliente.returnFormat)}')
# Out:
# Formato de retorno fijado a json.
#       ¿Confirma el servidor que lo acepta? :      True

# %% [markdown]
# ### Consulta que se pretende remitir
# Se va a almacenar una consulta SPARQL adeduada a Wikidata en la variable `consulta`. El texto de esta consulta se incorpora al objeto `cliente` en el atributo `.queryString` mediante el método `setQuery()`.
#
# En este caso se preguntará a Wikidata por _"cuadros que representan un funeral, con su autor y su imagen si estuviera disponible"_. El diseño de esta consulta se podía haber realizado externamente sobre el interfaz web que facilita Wikidata, como se muestra en [este enlace a la consulta](https://query.wikidata.org/#%231%20Cada%20entidad%20%28%3Fcuadro%29%20perteneciente%20%28P31%29%20a%20la%20clase%20%27pintura%27%20%28Q3305213%29%0A%232%20que%20tenga%20relación%20%27representa%27%20%28P180%29%20con%20%27funeral%27%20%28Q201676%29%20y%0A%233%20que%20tiene%20por%20autor%20%28P170%29%20a%20%3Fautor%0A%234%20Y%2C%20opcionalmente%2C%20que%20tenga%20por%20imagen%20%28P18%29%20a%20%3Fimagen%0A%23%20%28la%20variable%20%3Frepresenta%20se%20fija%20al%20texto%20%22funeral%22%20por%20legilibidad%20de%20resultados%29%0A%0ASELECT%20%3Fcuadro%20%3FcuadroLabel%20%20%3Fautor%20%3FautorLabel%20%3Frepresenta%20%3Fimagen%0AWHERE%20%7B%0A%20%20BIND%28%22funeral%22%20as%20%3Frepresenta%29%0A%20%20%3Fcuadro%20wdt%3AP31%20wd%3AQ3305213%20.%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%231%0A%20%20%3Fcuadro%20wdt%3AP180%20wd%3AQ201676%20.%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%232%0A%20%20%3Fcuadro%20wdt%3AP170%20%3Fautor.%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%233%0A%20%20OPTIONAL%20%7B%3Fcuadro%20wdt%3AP18%20%20%3Fimagen%7D%20%20%20%20%20%20%20%20%20%20%234%0A%20%20SERVICE%20wikibase%3Alabel%20%7B%20%0A%20%20%20%20bd%3AserviceParam%20wikibase%3Alanguage%20%22es%2Cen%22.%20%7D%20%20%23etiquetas%20en%20español%20o%20inglés%0A%7D%0A)
#
# Hay que observar que la dirección del interfaz web de consulta de Wikidata es [https://query.wikidata.org](https://query.wikidata.org) pero esta página remite la consulta a SPARQL end-point en [https://query.wikidata.org/sparql](https://query.wikidata.org/sparql), como también hacemos desde nuestro cliente local de consulta.

# %%
consulta = '''
SELECT ?cuadro ?cuadroLabel  ?autor ?autorLabel ?representa ?imagen
WHERE {
  BIND("funeral" as ?representa)
  # ?cuadro wdt:P31 wd:Q3305213 .
  # ?cuadro wdt:P180 wd:Q201676 .
  # ?cuadro wdt:P170 ?autor.          
  OPTIONAL {?cuadro wdt:P18  ?imagen}
  SERVICE wikibase:label { 
    bd:serviceParam wikibase:language "es,en". }  #etiquetas en español o inglés
}
'''

cliente.setQuery(consulta)

# %% [markdown]
# ## Recepción de resultados

# %% [markdown]
# ### El objeto respuesta
# El método [.query()](https://sparqlwrapper.readthedocs.io/en/latest/SPARQLWrapper.Wrapper.html#SPARQLWrapper.Wrapper.SPARQLWrapper.query) ejecuta la consulta. La respuesta recibida se encapsula en un objeto de la clase  [QueryResult](https://sparqlwrapper.readthedocs.io/en/latest/SPARQLWrapper.Wrapper.html#SPARQLWrapper.Wrapper.QueryResult)

# %%
# Envío de consulta y recepción de resultados
respuesta_queryresult = cliente.query()

print(f'El objeto que encapsula la respuesta es de tipo\n \
{type(respuesta_queryresult)}')

print(f'El formato de respuesta ha sido finalmente {respuesta_queryresult._get_responseFormat()}')
# Out:
# El objeto que encapsula la respuesta es de tipo
#  <class 'SPARQLWrapper.Wrapper.QueryResult'>
# El formato de respuesta ha sido finalmente json

# %% [markdown]
# ### Serialización de la respuesta
# QueryResult tiene un método `.convert()` que exporta los datos encapsulados en un formato de salida que [depende del formato en que se recibieron](https://sparqlwrapper.readthedocs.io/en/latest/_modules/SPARQLWrapper/Wrapper.html#QueryResult.convert) los datos. Para resultados recibidos en JSON la exportación tiene la estructura de un diccionario Python.
#
# La respuesta a esta consulta SELECT se solicitó en formato JSON. Otros formatos posibles para una consulta SELECT son XML, CSV o TSV.
#
# La composición de ejecución de consulta y de conversión, `.query().convert()`, obviamente se podía haber ejecutado como `cliente.query().convert()` y también mediante llamada al macro `queryAndConvert()`.

# %%
respuesta_dicc = respuesta_queryresult.convert()

print(f'Estructura de los datos exportados\n \
     {type(respuesta_dicc)}')
# Out:
# Estructura de los datos exportados
#       <class 'dict'>

# %% [markdown]
# La siguiente celda secuencia este diccionario con el método `json.dumps` y lo imprime de forma legible.

# %%
import json
print( json.dumps(respuesta_dicc, indent=1) )
# Out:
# {
#  "head": {
#   "vars": [
#    "cuadro",
#    "cuadroLabel",
#    "autor",
#    "autorLabel",
#    "representa",
#    "imagen"
#   ]
#  },
#  "results": {
#   "bindings": [
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q94802"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q301"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/El%20Greco%20-%20The%20Burial%20of%20the%20Count%20of%20Orgaz.JPG"
#     },
#     "cuadroLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "El entierro del Conde de Orgaz"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "El Greco"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q470541"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q159606"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Millais%20-%20Das%20Tal%20der%20Stille.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "The Vale of Rest"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "John Everett Millais"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q2494850"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q40599"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/The%20Funeral%20MET%20DT1931.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "The Funeral"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "\u00c9douard Manet"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q3850297"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q5581"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Vittore%20Carpaccio%20083.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "Martyrdom of the Pilgrims and Funeral of Saint Ursula"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Vittore Carpaccio"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q16687609"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q12844811"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "The Funeral of Ferdowsi"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Ghazanfar Khaligov"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q17339396"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q454678"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Het%20laatste%20oordeel%20en%20het%20begraven%20der%20doden%20Rijksmuseum%20SK-A-4265.jpeg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "The Last Judgement and the burial of the dead"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Bernard van Orley"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q18689517"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q2841491"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Luis%20Montero%20-%20The%20Funerals%20of%20Inca%20Atahualpa%20-%20Google%20Art%20Project.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Los funerales de Atahualpa"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Luis Montero"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q20175647"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q20822488"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Infant%20Funeral%20Procession%20MET%20DP-1427-015.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "Infant Funeral Procession"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "William P. Chappel"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q20175693"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q20822488"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Adult%20Funeral%20Procession%20MET%20DP-1427-019.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "Adult Funeral Procession"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "William P. Chappel"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q20188034"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q1689515"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/The%20Funeral%20of%20Lucretia%20MET%20DP328375.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "The Funeral of Lucretia"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Master of Marradi"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q20491541"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q253446"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/En%20begravelse.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "A Funeral"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Anna Ancher"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q20504561"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q12899967"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Porte%20St.%20Martin%20et%20Enterrement-1952.13.129%201.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "Porte St. Martin et Enterrement"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Frank Edwin Scott"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q20540825"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q3330927"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Joseph%20Henry%20Sharp%20-%20The%20Voice%20of%20the%20Great%20Spirit%20%281906%29.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "The Voice of the Great Spirit"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Joseph Henry Sharp"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q21127247"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q2362227"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/En%20ligf%C3%A6rd%20Motiv%20fra%20det%20nordlige%20Sj%C3%A6lland.jpg"
#     },
#     "cuadroLabel": {
#      "type": "literal",
#      "value": "Q21127247"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "J\u00f8rgen Sonne"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q23015473"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q16563806"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Julian%20Karczewski%20-%20Jewish%20funeral%20in%20Vilnius%20in%201824%20-%20MP%20130%20-%20National%20Museum%20in%20Warsaw.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "Jewish funeral in Vilnius in 1824."
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Julian Karczewski"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q23015473"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q16563806"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Karczewski%20Jewish%20funeral.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "Jewish funeral in Vilnius in 1824."
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Julian Karczewski"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q25301914"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q1734185"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Karol%20Tichy%20-%20Elegy%20-%20MP%20382%20-%20National%20Museum%20in%20Warsaw.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "Elegy (Funeral)."
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Karol Tichy"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q27410621"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q159758"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Terner%202.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Peace Burial at Sea"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Joseph Mallord William Turner"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q27660082"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/.well-known/genid/0db1db6cd791e647155fb6df3a41de1a"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Nicolas%20Poussin%20-%20The%20Burial%20of%20Phocion.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "The Funeral of Phocion"
#     },
#     "autorLabel": {
#      "type": "literal",
#      "value": "http://www.wikidata.org/.well-known/genid/0db1db6cd791e647155fb6df3a41de1a"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q28803752"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q2978902"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "Funeral"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Clementina Hunter"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q50119754"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q16943911"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "Funeral of a Fisherman"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Augustin Hanicotte"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q62414997"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q24026864"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "The Funeral of Walter von Vogelweide"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Friedrich Arnold"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q64783368"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q1574250"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Charles%20Cottet%20Enterrement%20Breton.jpg"
#     },
#     "cuadroLabel": {
#      "type": "literal",
#      "value": "Q64783368"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Charles Cottet"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q78850480"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/.well-known/genid/79136c70b98998d608d1cc9f30f51d10"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Anonymous%20-%20%E2%80%9CLeaves%20of%20Wild%20Ginger%E2%80%9D%20%28Aoi%29%2C%20from%20the%20Phantom%20Genji%20Scrolls%20%28Maboroshi%20no%20Genji%20monogatari%20emaki%29%20-%2012.134.11%20-%20Metropolitan%20Museum%20of%20Art.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "\u201cLeaves of Wild Ginger\u201d (Aoi), from the Phantom Genji Scrolls (Maboroshi no Genji monogatari emaki)"
#     },
#     "autorLabel": {
#      "type": "literal",
#      "value": "http://www.wikidata.org/.well-known/genid/79136c70b98998d608d1cc9f30f51d10"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q96185338"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q1992876"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "Funeral Procession, Tomb of Ramose"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Nina M. Davies"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q96185389"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q1992876"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Funeral%20Procession%2C%20Tomb%20of%20Pairy%20MET%2035.101.3.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "Funeral Procession, Tomb of Pairy"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Nina M. Davies"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q99498893"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q1126926"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/The%20funeral%20of%20Rear%20Admiral%20Phillip%20Parker%20King%2C%201856%2C%20painted%20by%20Conrad%20Martens.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "The funeral of Rear Admiral Phillip Parker King, 1856, by Conrad Martens"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Conrad Martens"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q104352781"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/.well-known/genid/77e891d306de438d3184e8a63f7ef566"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Anonymous%20-%20Derniers%20honneurs%20rendus%20%C3%A0%20Benjamin%20Constant%2C%20au%20cimeti%C3%A8re%20du%20P%C3%A8re-Lachaise%2C%20le%2012%20d%C3%A9cembre%201830%20-%20P1342%20-%20Mus%C3%A9e%20Carnavalet.jpg"
#     },
#     "cuadroLabel": {
#      "type": "literal",
#      "value": "Q104352781"
#     },
#     "autorLabel": {
#      "type": "literal",
#      "value": "http://www.wikidata.org/.well-known/genid/77e891d306de438d3184e8a63f7ef566"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q104373401"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q24845169"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Ernest%20Jean%20Delahaye%20-%20Les%20mutil%C3%A9s%20assistent%20aux%20obs%C3%A8ques%20du%20g%C3%A9n%C3%A9ral%20Galli%C3%A9ni%2C%20sur%20la%20place%20de%20l%27H%C3%B4tel-de-Ville%20%281er%20juin%201916%29%20-%20P1266%20-%20Mus%C3%A9e%20Carnavalet.jpg"
#     },
#     "cuadroLabel": {
#      "type": "literal",
#      "value": "Q104373401"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Ernest-Jean Delahaye"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q104373641"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q15970262"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Guiaud%20-%20Pompes%20fun%C3%A8bres%20du%20duc%20d%27Orl%C3%A9ans%20%C3%A0%20Notre-Dame%2C%20le%2030%20juillet%201842.jpg"
#     },
#     "cuadroLabel": {
#      "type": "literal",
#      "value": "Q104373641"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Jacques Guiaud"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q104387292"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q104406941"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Fougeat%20-%20Fun%C3%A9railles%20de%20Marat%2C%20%C3%A0%20l%27%C3%A9glise%20des%20Cordeliers%2C%20les%2015%20et%2016%20juillet%201793%20-%20P70%20-%20Mus%C3%A9e%20Carnavalet.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "Funeral of Marat, at the Cordeliers church, July 15 and 16, 1793"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Fougeat"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q104445485"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q968357"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Jean-Joseph%20Benjamin-Constant%20-%20Le%20jour%20des%20fun%C3%A9railles%20-%20Sc%C3%A8ne%20du%20Maroc%20-%20PPP155%20-%20mus%C3%A9e%20des%20Beaux-Arts%20de%20la%20ville%20de%20Paris.jpg"
#     },
#     "cuadroLabel": {
#      "type": "literal",
#      "value": "Q104445485"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Jean-Joseph Benjamin-Constant"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q104472038"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q1682309"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Jan%20Van%20Beers%20-%20Les%20fun%C3%A9railles%20de%20Charles%20le%20Bon%2C%20comte%20de%20Flandre%2C%20c%C3%A9l%C3%A9br%C3%A9es%20%C3%A0%20Bruges%20le%2022%20avril%201127%20-%20PDUT1507%20-%20mus%C3%A9e%20des%20Beaux-Arts%20de%20la%20ville%20de%20Paris.jpg"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "The funeral of Charles I, Count of Flanders, celebrated in Bruges in the Church of St. Christopher on 22 April 1127"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Jan van Beers"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q104765380"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q570293"
#     },
#     "cuadroLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "Hutsul Funeral"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Fryderyk Pautsch"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q106350729"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q708568"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Jean-Paul%20Laurens%20-%20Fun%C3%A9railles%2001.jpg"
#     },
#     "cuadroLabel": {
#      "type": "literal",
#      "value": "Q106350729"
#     },
#     "autorLabel": {
#      "xml:lang": "es",
#      "type": "literal",
#      "value": "Jean-Paul Laurens"
#     }
#    },
#    {
#     "representa": {
#      "type": "literal",
#      "value": "funeral"
#     },
#     "cuadro": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q106671032"
#     },
#     "autor": {
#      "type": "uri",
#      "value": "http://www.wikidata.org/entity/Q90697597"
#     },
#     "imagen": {
#      "type": "uri",
#      "value": "http://commons.wikimedia.org/wiki/Special:FilePath/Les%20fun%C3%A9railles%20du%20terre-neuvas.jpg"
#     },
#     "cuadroLabel": {
#      "type": "literal",
#      "value": "Q106671032"
#     },
#     "autorLabel": {
#      "xml:lang": "en",
#      "type": "literal",
#      "value": "Henri-Edmond Rudaux"
#     }
#    }
#   ]
#  }
# }

# %% [markdown]
# En esta exportación json del diccionario se reconoce la estructura [estandarizada](https://www.w3.org/TR/sparql11-results-json/) en que cualquier servidor SPARQL debe responder si se solicita retorno en JSON:
#
# ```json
# {
#  'head':
#     {'vars':
#       ['var0', 'var1', ...]
#     },
#  'results':
#     {'bindings':
#        [
#          {
#            'var0': {'type':xxx, 'value':xxx, 'xml:lang':xxx}},
#            'var1': {'type':xxx, 'value':xxx, 'xml:lang':xxx}}
#            ...
#          }
#          {
#            'var0': {'type':xxx, 'value':xxx, 'xml:lang':xxx}},
#            'var1': {'type':xxx, 'value':xxx, 'xml:lang':xxx}}
#            ...
#          }
#        ]
#     }
# }
# ```
#
# Es decir, `bindings` es una lista de elementos que son diccionarios. Cada uno de estos diccionarios tiene:
# + una clave (una _var_ de las que se encuentran también en la lista `vars` y que corresponden a las variables que se solicitaron en la cabecera de la consulta SELECT)
# + su correspondiente valor, que es a su vez un diccionario con valores para las claves `value`, `type` y opcionalmente `xml:lang` para esa _var_.

# %%
for elem in respuesta_dicc['results']['bindings']:
    for elem_key, elem_dicc in elem.items():
        print(f'* {elem_key}:')
        for elem_dicc_key, elem_dicc_value in elem_dicc.items():
            print(f'  + {elem_dicc_key} --> {elem_dicc_value}' )
    print('----------\n')
# Out:
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q94802
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q301
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/El%20Greco%20-%20The%20Burial%20of%20the%20Count%20of%20Orgaz.JPG
# * cuadroLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> El entierro del Conde de Orgaz
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> El Greco
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q470541
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q159606
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Millais%20-%20Das%20Tal%20der%20Stille.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> The Vale of Rest
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> John Everett Millais
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q2494850
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q40599
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/The%20Funeral%20MET%20DT1931.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> The Funeral
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Édouard Manet
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q3850297
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q5581
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Vittore%20Carpaccio%20083.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> Martyrdom of the Pilgrims and Funeral of Saint Ursula
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Vittore Carpaccio
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q16687609
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q12844811
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> The Funeral of Ferdowsi
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Ghazanfar Khaligov
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q17339396
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q454678
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Het%20laatste%20oordeel%20en%20het%20begraven%20der%20doden%20Rijksmuseum%20SK-A-4265.jpeg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> The Last Judgement and the burial of the dead
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Bernard van Orley
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q18689517
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q2841491
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Luis%20Montero%20-%20The%20Funerals%20of%20Inca%20Atahualpa%20-%20Google%20Art%20Project.jpg
# * cuadroLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Los funerales de Atahualpa
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Luis Montero
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q20175647
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q20822488
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Infant%20Funeral%20Procession%20MET%20DP-1427-015.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> Infant Funeral Procession
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> William P. Chappel
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q20175693
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q20822488
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Adult%20Funeral%20Procession%20MET%20DP-1427-019.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> Adult Funeral Procession
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> William P. Chappel
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q20188034
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q1689515
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/The%20Funeral%20of%20Lucretia%20MET%20DP328375.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> The Funeral of Lucretia
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Master of Marradi
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q20491541
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q253446
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/En%20begravelse.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> A Funeral
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Anna Ancher
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q20504561
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q12899967
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Porte%20St.%20Martin%20et%20Enterrement-1952.13.129%201.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> Porte St. Martin et Enterrement
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Frank Edwin Scott
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q20540825
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q3330927
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Joseph%20Henry%20Sharp%20-%20The%20Voice%20of%20the%20Great%20Spirit%20%281906%29.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> The Voice of the Great Spirit
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Joseph Henry Sharp
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q21127247
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q2362227
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/En%20ligf%C3%A6rd%20Motiv%20fra%20det%20nordlige%20Sj%C3%A6lland.jpg
# * cuadroLabel:
#   + type --> literal
#   + value --> Q21127247
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Jørgen Sonne
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q23015473
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q16563806
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Julian%20Karczewski%20-%20Jewish%20funeral%20in%20Vilnius%20in%201824%20-%20MP%20130%20-%20National%20Museum%20in%20Warsaw.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> Jewish funeral in Vilnius in 1824.
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Julian Karczewski
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q23015473
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q16563806
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Karczewski%20Jewish%20funeral.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> Jewish funeral in Vilnius in 1824.
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Julian Karczewski
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q25301914
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q1734185
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Karol%20Tichy%20-%20Elegy%20-%20MP%20382%20-%20National%20Museum%20in%20Warsaw.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> Elegy (Funeral).
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Karol Tichy
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q27410621
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q159758
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Terner%202.jpg
# * cuadroLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Peace Burial at Sea
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Joseph Mallord William Turner
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q27660082
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/.well-known/genid/0db1db6cd791e647155fb6df3a41de1a
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Nicolas%20Poussin%20-%20The%20Burial%20of%20Phocion.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> The Funeral of Phocion
# * autorLabel:
#   + type --> literal
#   + value --> http://www.wikidata.org/.well-known/genid/0db1db6cd791e647155fb6df3a41de1a
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q28803752
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q2978902
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> Funeral
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Clementina Hunter
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q50119754
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q16943911
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> Funeral of a Fisherman
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Augustin Hanicotte
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q62414997
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q24026864
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> The Funeral of Walter von Vogelweide
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Friedrich Arnold
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q64783368
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q1574250
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Charles%20Cottet%20Enterrement%20Breton.jpg
# * cuadroLabel:
#   + type --> literal
#   + value --> Q64783368
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Charles Cottet
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q78850480
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/.well-known/genid/79136c70b98998d608d1cc9f30f51d10
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Anonymous%20-%20%E2%80%9CLeaves%20of%20Wild%20Ginger%E2%80%9D%20%28Aoi%29%2C%20from%20the%20Phantom%20Genji%20Scrolls%20%28Maboroshi%20no%20Genji%20monogatari%20emaki%29%20-%2012.134.11%20-%20Metropolitan%20Museum%20of%20Art.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> “Leaves of Wild Ginger” (Aoi), from the Phantom Genji Scrolls (Maboroshi no Genji monogatari emaki)
# * autorLabel:
#   + type --> literal
#   + value --> http://www.wikidata.org/.well-known/genid/79136c70b98998d608d1cc9f30f51d10
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q96185338
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q1992876
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> Funeral Procession, Tomb of Ramose
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Nina M. Davies
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q96185389
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q1992876
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Funeral%20Procession%2C%20Tomb%20of%20Pairy%20MET%2035.101.3.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> Funeral Procession, Tomb of Pairy
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Nina M. Davies
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q99498893
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q1126926
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/The%20funeral%20of%20Rear%20Admiral%20Phillip%20Parker%20King%2C%201856%2C%20painted%20by%20Conrad%20Martens.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> The funeral of Rear Admiral Phillip Parker King, 1856, by Conrad Martens
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Conrad Martens
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q104352781
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/.well-known/genid/77e891d306de438d3184e8a63f7ef566
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Anonymous%20-%20Derniers%20honneurs%20rendus%20%C3%A0%20Benjamin%20Constant%2C%20au%20cimeti%C3%A8re%20du%20P%C3%A8re-Lachaise%2C%20le%2012%20d%C3%A9cembre%201830%20-%20P1342%20-%20Mus%C3%A9e%20Carnavalet.jpg
# * cuadroLabel:
#   + type --> literal
#   + value --> Q104352781
# * autorLabel:
#   + type --> literal
#   + value --> http://www.wikidata.org/.well-known/genid/77e891d306de438d3184e8a63f7ef566
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q104373401
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q24845169
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Ernest%20Jean%20Delahaye%20-%20Les%20mutil%C3%A9s%20assistent%20aux%20obs%C3%A8ques%20du%20g%C3%A9n%C3%A9ral%20Galli%C3%A9ni%2C%20sur%20la%20place%20de%20l%27H%C3%B4tel-de-Ville%20%281er%20juin%201916%29%20-%20P1266%20-%20Mus%C3%A9e%20Carnavalet.jpg
# * cuadroLabel:
#   + type --> literal
#   + value --> Q104373401
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Ernest-Jean Delahaye
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q104373641
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q15970262
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Guiaud%20-%20Pompes%20fun%C3%A8bres%20du%20duc%20d%27Orl%C3%A9ans%20%C3%A0%20Notre-Dame%2C%20le%2030%20juillet%201842.jpg
# * cuadroLabel:
#   + type --> literal
#   + value --> Q104373641
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Jacques Guiaud
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q104387292
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q104406941
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Fougeat%20-%20Fun%C3%A9railles%20de%20Marat%2C%20%C3%A0%20l%27%C3%A9glise%20des%20Cordeliers%2C%20les%2015%20et%2016%20juillet%201793%20-%20P70%20-%20Mus%C3%A9e%20Carnavalet.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> Funeral of Marat, at the Cordeliers church, July 15 and 16, 1793
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Fougeat
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q104445485
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q968357
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Jean-Joseph%20Benjamin-Constant%20-%20Le%20jour%20des%20fun%C3%A9railles%20-%20Sc%C3%A8ne%20du%20Maroc%20-%20PPP155%20-%20mus%C3%A9e%20des%20Beaux-Arts%20de%20la%20ville%20de%20Paris.jpg
# * cuadroLabel:
#   + type --> literal
#   + value --> Q104445485
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Jean-Joseph Benjamin-Constant
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q104472038
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q1682309
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Jan%20Van%20Beers%20-%20Les%20fun%C3%A9railles%20de%20Charles%20le%20Bon%2C%20comte%20de%20Flandre%2C%20c%C3%A9l%C3%A9br%C3%A9es%20%C3%A0%20Bruges%20le%2022%20avril%201127%20-%20PDUT1507%20-%20mus%C3%A9e%20des%20Beaux-Arts%20de%20la%20ville%20de%20Paris.jpg
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> The funeral of Charles I, Count of Flanders, celebrated in Bruges in the Church of St. Christopher on 22 April 1127
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Jan van Beers
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q104765380
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q570293
# * cuadroLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> Hutsul Funeral
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Fryderyk Pautsch
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q106350729
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q708568
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Jean-Paul%20Laurens%20-%20Fun%C3%A9railles%2001.jpg
# * cuadroLabel:
#   + type --> literal
#   + value --> Q106350729
# * autorLabel:
#   + xml:lang --> es
#   + type --> literal
#   + value --> Jean-Paul Laurens
# ----------
#
# * representa:
#   + type --> literal
#   + value --> funeral
# * cuadro:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q106671032
# * autor:
#   + type --> uri
#   + value --> http://www.wikidata.org/entity/Q90697597
# * imagen:
#   + type --> uri
#   + value --> http://commons.wikimedia.org/wiki/Special:FilePath/Les%20fun%C3%A9railles%20du%20terre-neuvas.jpg
# * cuadroLabel:
#   + type --> literal
#   + value --> Q106671032
# * autorLabel:
#   + xml:lang --> en
#   + type --> literal
#   + value --> Henri-Edmond Rudaux
# ----------

# %% [markdown]
# ##  Dataframe con las respuestas
# Los datos obtenidos se pueden almacenar en algún tipo de base de datos y/o procesar. El paquete `pandas` permite gestionar este tipo de datos tabulares.

# %%
import pandas as pd

# %% [markdown]
# Pandas facilita [pandas.json_normalize()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.json_normalize.html) que es un método para exportar datos de un diccionario, por mucho anidamiento que presente, a un DataFrame plano. Como este método trabaja sobre diccionarios y no sobre cadenas de caracteres JSON, lo ejecutaremos sobre `respuesta_dicc` en vez de sobre su volcado secuenciado. Para comprobar que se ha construido el DataFrame, se imprime a continuación un resumen del mismo.

# %%
respuesta_df = pd.json_normalize(respuesta_dicc,['results','bindings'])
respuesta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   representa.type       36 non-null     object
#  1   representa.value      36 non-null     object
#  2   cuadro.type           36 non-null     object
#  3   cuadro.value          36 non-null     object
#  4   autor.type            36 non-null     object
#  5   autor.value           36 non-null     object
#  6   imagen.type           30 non-null     object
#  7   imagen.value          30 non-null     object
#  8   cuadroLabel.xml:lang  28 non-null     object
#  9   cuadroLabel.type      36 non-null     object
#  10  cuadroLabel.value     36 non-null     object
#  11  autorLabel.xml:lang   33 non-null     object
#  12  autorLabel.type       36 non-null     object
#  13  autorLabel.value      36 non-null     object
# dtypes: object(14)
# memory usage: 4.1+ KB

# %% [markdown]
# La presentación completa del DataFrame, conforme al resumen previo, produce la siguiente tabla.

# %%
respuesta_df
# Out:
#    representa.type representa.value cuadro.type  \
# 0          literal          funeral         uri
# 1          literal          funeral         uri
# 2          literal          funeral         uri
# 3          literal          funeral         uri
# 4          literal          funeral         uri
# 5          literal          funeral         uri
# 6          literal          funeral         uri
# 7          literal          funeral         uri
# 8          literal          funeral         uri
# 9          literal          funeral         uri
# 10         literal          funeral         uri
# 11         literal          funeral         uri
# 12         literal          funeral         uri
# 13         literal          funeral         uri
# 14         literal          funeral         uri
# 15         literal          funeral         uri
# 16         literal          funeral         uri
# 17         literal          funeral         uri
# 18         literal          funeral         uri
# 19         literal          funeral         uri
# 20         literal          funeral         uri
# 21         literal          funeral         uri
# 22         literal          funeral         uri
# 23         literal          funeral         uri
# 24         literal          funeral         uri
# 25         literal          funeral         uri
# 26         literal          funeral         uri
# 27         literal          funeral         uri
# 28         literal          funeral         uri
# 29         literal          funeral         uri
# 30         literal          funeral         uri
# 31         literal          funeral         uri
# 32         literal          funeral         uri
# 33         literal          funeral         uri
# 34         literal          funeral         uri
# 35         literal          funeral         uri
#
#                                  cuadro.value autor.type  \
# 0       http://www.wikidata.org/entity/Q94802        uri
# 1      http://www.wikidata.org/entity/Q470541        uri
# 2     http://www.wikidata.org/entity/Q2494850        uri
# 3     http://www.wikidata.org/entity/Q3850297        uri
# 4    http://www.wikidata.org/entity/Q16687609        uri
# 5    http://www.wikidata.org/entity/Q17339396        uri
# 6    http://www.wikidata.org/entity/Q18689517        uri
# 7    http://www.wikidata.org/entity/Q20175647        uri
# 8    http://www.wikidata.org/entity/Q20175693        uri
# 9    http://www.wikidata.org/entity/Q20188034        uri
# 10   http://www.wikidata.org/entity/Q20491541        uri
# 11   http://www.wikidata.org/entity/Q20504561        uri
# 12   http://www.wikidata.org/entity/Q20540825        uri
# 13   http://www.wikidata.org/entity/Q21127247        uri
# 14   http://www.wikidata.org/entity/Q23015473        uri
# 15   http://www.wikidata.org/entity/Q23015473        uri
# 16   http://www.wikidata.org/entity/Q25301914        uri
# 17   http://www.wikidata.org/entity/Q27410621        uri
# 18   http://www.wikidata.org/entity/Q27660082        uri
# 19   http://www.wikidata.org/entity/Q28803752        uri
# 20   http://www.wikidata.org/entity/Q50119754        uri
# 21   http://www.wikidata.org/entity/Q62414997        uri
# 22   http://www.wikidata.org/entity/Q64783368        uri
# 23   http://www.wikidata.org/entity/Q78850480        uri
# 24   http://www.wikidata.org/entity/Q96185338        uri
# 25   http://www.wikidata.org/entity/Q96185389        uri
# 26   http://www.wikidata.org/entity/Q99498893        uri
# 27  http://www.wikidata.org/entity/Q104352781        uri
# 28  http://www.wikidata.org/entity/Q104373401        uri
# 29  http://www.wikidata.org/entity/Q104373641        uri
# 30  http://www.wikidata.org/entity/Q104387292        uri
# 31  http://www.wikidata.org/entity/Q104445485        uri
# 32  http://www.wikidata.org/entity/Q104472038        uri
# 33  http://www.wikidata.org/entity/Q104765380        uri
# 34  http://www.wikidata.org/entity/Q106350729        uri
# 35  http://www.wikidata.org/entity/Q106671032        uri
#
#                                           autor.value imagen.type  \
# 0                 http://www.wikidata.org/entity/Q301         uri
# 1              http://www.wikidata.org/entity/Q159606         uri
# 2               http://www.wikidata.org/entity/Q40599         uri
# 3                http://www.wikidata.org/entity/Q5581         uri
# 4            http://www.wikidata.org/entity/Q12844811         NaN
# 5              http://www.wikidata.org/entity/Q454678         uri
# 6             http://www.wikidata.org/entity/Q2841491         uri
# 7            http://www.wikidata.org/entity/Q20822488         uri
# 8            http://www.wikidata.org/entity/Q20822488         uri
# 9             http://www.wikidata.org/entity/Q1689515         uri
# 10             http://www.wikidata.org/entity/Q253446         uri
# 11           http://www.wikidata.org/entity/Q12899967         uri
# 12            http://www.wikidata.org/entity/Q3330927         uri
# 13            http://www.wikidata.org/entity/Q2362227         uri
# 14           http://www.wikidata.org/entity/Q16563806         uri
# 15           http://www.wikidata.org/entity/Q16563806         uri
# 16            http://www.wikidata.org/entity/Q1734185         uri
# 17             http://www.wikidata.org/entity/Q159758         uri
# 18  http://www.wikidata.org/.well-known/genid/0db1...         uri
# 19            http://www.wikidata.org/entity/Q2978902         NaN
# 20           http://www.wikidata.org/entity/Q16943911         NaN
# 21           http://www.wikidata.org/entity/Q24026864         NaN
# 22            http://www.wikidata.org/entity/Q1574250         uri
# 23  http://www.wikidata.org/.well-known/genid/7913...         uri
# 24            http://www.wikidata.org/entity/Q1992876         NaN
# 25            http://www.wikidata.org/entity/Q1992876         uri
# 26            http://www.wikidata.org/entity/Q1126926         uri
# 27  http://www.wikidata.org/.well-known/genid/77e8...         uri
# 28           http://www.wikidata.org/entity/Q24845169         uri
# 29           http://www.wikidata.org/entity/Q15970262         uri
# 30          http://www.wikidata.org/entity/Q104406941         uri
# 31             http://www.wikidata.org/entity/Q968357         uri
# 32            http://www.wikidata.org/entity/Q1682309         uri
# 33             http://www.wikidata.org/entity/Q570293         NaN
# 34             http://www.wikidata.org/entity/Q708568         uri
# 35           http://www.wikidata.org/entity/Q90697597         uri
#
#                                          imagen.value cuadroLabel.xml:lang  \
# 0   http://commons.wikimedia.org/wiki/Special:File...                   es
# 1   http://commons.wikimedia.org/wiki/Special:File...                   en
# 2   http://commons.wikimedia.org/wiki/Special:File...                   en
# 3   http://commons.wikimedia.org/wiki/Special:File...                   en
# 4                                                 NaN                   en
# 5   http://commons.wikimedia.org/wiki/Special:File...                   en
# 6   http://commons.wikimedia.org/wiki/Special:File...                   es
# 7   http://commons.wikimedia.org/wiki/Special:File...                   en
# 8   http://commons.wikimedia.org/wiki/Special:File...                   en
# 9   http://commons.wikimedia.org/wiki/Special:File...                   en
# 10  http://commons.wikimedia.org/wiki/Special:File...                   en
# 11  http://commons.wikimedia.org/wiki/Special:File...                   en
# 12  http://commons.wikimedia.org/wiki/Special:File...                   en
# 13  http://commons.wikimedia.org/wiki/Special:File...                  NaN
# 14  http://commons.wikimedia.org/wiki/Special:File...                   en
# 15  http://commons.wikimedia.org/wiki/Special:File...                   en
# 16  http://commons.wikimedia.org/wiki/Special:File...                   en
# 17  http://commons.wikimedia.org/wiki/Special:File...                   es
# 18  http://commons.wikimedia.org/wiki/Special:File...                   en
# 19                                                NaN                   en
# 20                                                NaN                   en
# 21                                                NaN                   en
# 22  http://commons.wikimedia.org/wiki/Special:File...                  NaN
# 23  http://commons.wikimedia.org/wiki/Special:File...                   en
# 24                                                NaN                   en
# 25  http://commons.wikimedia.org/wiki/Special:File...                   en
# 26  http://commons.wikimedia.org/wiki/Special:File...                   en
# 27  http://commons.wikimedia.org/wiki/Special:File...                  NaN
# 28  http://commons.wikimedia.org/wiki/Special:File...                  NaN
# 29  http://commons.wikimedia.org/wiki/Special:File...                  NaN
# 30  http://commons.wikimedia.org/wiki/Special:File...                   en
# 31  http://commons.wikimedia.org/wiki/Special:File...                  NaN
# 32  http://commons.wikimedia.org/wiki/Special:File...                   en
# 33                                                NaN                   en
# 34  http://commons.wikimedia.org/wiki/Special:File...                  NaN
# 35  http://commons.wikimedia.org/wiki/Special:File...                  NaN
#
#    cuadroLabel.type                                  cuadroLabel.value  \
# 0           literal                     El entierro del Conde de Orgaz
# 1           literal                                   The Vale of Rest
# 2           literal                                        The Funeral
# 3           literal  Martyrdom of the Pilgrims and Funeral of Saint...
# 4           literal                            The Funeral of Ferdowsi
# 5           literal      The Last Judgement and the burial of the dead
# 6           literal                         Los funerales de Atahualpa
# 7           literal                          Infant Funeral Procession
# 8           literal                           Adult Funeral Procession
# 9           literal                            The Funeral of Lucretia
# 10          literal                                          A Funeral
# 11          literal                    Porte St. Martin et Enterrement
# 12          literal                      The Voice of the Great Spirit
# 13          literal                                          Q21127247
# 14          literal                 Jewish funeral in Vilnius in 1824.
# 15          literal                 Jewish funeral in Vilnius in 1824.
# 16          literal                                   Elegy (Funeral).
# 17          literal                                Peace Burial at Sea
# 18          literal                             The Funeral of Phocion
# 19          literal                                            Funeral
# 20          literal                             Funeral of a Fisherman
# 21          literal               The Funeral of Walter von Vogelweide
# 22          literal                                          Q64783368
# 23          literal  “Leaves of Wild Ginger” (Aoi), from the Phanto...
# 24          literal                 Funeral Procession, Tomb of Ramose
# 25          literal                  Funeral Procession, Tomb of Pairy
# 26          literal  The funeral of Rear Admiral Phillip Parker Kin...
# 27          literal                                         Q104352781
# 28          literal                                         Q104373401
# 29          literal                                         Q104373641
# 30          literal  Funeral of Marat, at the Cordeliers church, Ju...
# 31          literal                                         Q104445485
# 32          literal  The funeral of Charles I, Count of Flanders, c...
# 33          literal                                     Hutsul Funeral
# 34          literal                                         Q106350729
# 35          literal                                         Q106671032
#
#    autorLabel.xml:lang autorLabel.type  \
# 0                   es         literal
# 1                   es         literal
# 2                   es         literal
# 3                   es         literal
# 4                   es         literal
# 5                   es         literal
# 6                   es         literal
# 7                   es         literal
# 8                   es         literal
# 9                   es         literal
# 10                  es         literal
# 11                  es         literal
# 12                  es         literal
# 13                  es         literal
# 14                  es         literal
# 15                  es         literal
# 16                  es         literal
# 17                  es         literal
# 18                 NaN         literal
# 19                  es         literal
# 20                  es         literal
# 21                  es         literal
# 22                  es         literal
# 23                 NaN         literal
# 24                  es         literal
# 25                  es         literal
# 26                  es         literal
# 27                 NaN         literal
# 28                  es         literal
# 29                  es         literal
# 30                  es         literal
# 31                  es         literal
# 32                  es         literal
# 33                  es         literal
# 34                  es         literal
# 35                  en         literal
#
#                                      autorLabel.value
# 0                                            El Greco
# 1                                John Everett Millais
# 2                                       Édouard Manet
# 3                                   Vittore Carpaccio
# 4                                  Ghazanfar Khaligov
# 5                                   Bernard van Orley
# 6                                        Luis Montero
# 7                                  William P. Chappel
# 8                                  William P. Chappel
# 9                                   Master of Marradi
# 10                                        Anna Ancher
# 11                                  Frank Edwin Scott
# 12                                 Joseph Henry Sharp
# 13                                       Jørgen Sonne
# 14                                  Julian Karczewski
# 15                                  Julian Karczewski
# 16                                        Karol Tichy
# 17                      Joseph Mallord William Turner
# 18  http://www.wikidata.org/.well-known/genid/0db1...
# 19                                  Clementina Hunter
# 20                                 Augustin Hanicotte
# 21                                   Friedrich Arnold
# 22                                     Charles Cottet
# 23  http://www.wikidata.org/.well-known/genid/7913...
# 24                                     Nina M. Davies
# 25                                     Nina M. Davies
# 26                                     Conrad Martens
# 27  http://www.wikidata.org/.well-known/genid/77e8...
# 28                               Ernest-Jean Delahaye
# 29                                     Jacques Guiaud
# 30                                            Fougeat
# 31                      Jean-Joseph Benjamin-Constant
# 32                                      Jan van Beers
# 33                                   Fryderyk Pautsch
# 34                                  Jean-Paul Laurens
# 35                                Henri-Edmond Rudaux
